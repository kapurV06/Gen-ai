# %% [markdown]
# <a href="https://colab.research.google.com/github/kapurV06/Gen-ai/blob/main/groq_llm_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install groq

# %%
import os

# %%
os.environ["GROQ_API_KEY"] = "your-api-key"

# %%
from groq import Groq

client = Groq()

chat_completions = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system", "content":"You are a helpful assistant."},
        {"role":"user", "content":"what is deeplearning ?"}
    ]
)

print(chat_completions.choices[0].message.content)
# Out:
# Deep learning is a subset of machine learning that involves the use of artificial neural networks (ANNs) to analyze and interpret data. It is a type of deep neural network that consists of multiple layers of interconnected nodes or "neurons" that process and transform inputs into meaningful outputs.
#
# Deep learning is inspired by the structure and function of the human brain, with layers of neurons working together to recognize patterns and make predictions. The most common type of deep learning is convolutional neural networks (CNNs), recurrent neural networks (RNNs), and generative adversarial networks (GANs).
#
# Deep learning is useful in various tasks such as:
#
# 1. **Image recognition**: identifying objects, scenes, and activities in images and videos.
# 2. **Speech recognition**: converting spoken words into text.
# 3. **Natural Language Processing (NLP)**: understanding the meaning and context of text and speech.
# 4. **Robotics**: control and navigation of robots.
# ...

# %%
from groq import Groq

client = Groq()

chat_completions = client.chat.completions.create(
    model = "llama-3.1-8b-instant",
    messages = [
        {"role":"system", "content":"You are a helpful assistant."},
        {"role":"user", "content":"what is deeplearning ?"},
        {"role":"assistant","content":"as if i know"},
        {"role":"user","content":"why"}

    ]
)

print(chat_completions.choices[0].message.content)
# Out:
# Deep learning is a subfield of machine learning that focuses on the development of algorithms and statistical models that closely resemble the structure and function of the human brain, particularly in the way it processes and learns from data. It involves the use of artificial neural networks, which are composed of layers of interconnected nodes (neurons) that process and transmit information.
#
# Here are some key reasons why deep learning is useful and has gained immense popularity:
#
# 1. **Pattern recognition**: Deep learning algorithms are capable of recognizing complex patterns in data, such as images, speech, and text, with a high degree of accuracy.
# 2. **Feature learning**: Deep learning models can automatically learn relevant features from data, reducing the need for manual feature engineering.
# 3. **Robustness to noise**: Deep learning models can tolerate significant amounts of noise in data, making them more robust to variations and errors.
# ...
